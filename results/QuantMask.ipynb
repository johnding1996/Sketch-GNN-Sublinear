# %% [markdown]
# # Quantization Mask

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from scgnn.mask import *

# %%
size = 64
freqs = np.linspace(0.0, 2.0, 64)
avg_deg = 4
nlayer = 3
org_size = 8

# %% [markdown]
# ### Theoretical Predicted Spectral Responses of Multi-Layer GCNs with ReLU Activation

# %%
plot_predicted_spectral_response(size, freqs, avg_deg, max_nlayer=nlayer, activation='ReLU')

# %% [markdown]
# ### Internel Offset Parameter of Quantization Masks vs. Desired Compress Ratio

# %%
plot_offset_vs_compress_ratio(size, freqs, avg_deg, nlayer, org_size)

# %% [markdown]
# ### Quantization Masks corresp. to Different Desired Compress Ratios in a 3-Layer GCN with ReLU

# %%
plot_predicted_quantization_mask(size, freqs, avg_deg, nlayer, org_size, activation='ReLU')
